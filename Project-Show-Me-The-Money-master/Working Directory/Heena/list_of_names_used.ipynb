# %% [markdown]
# Names used:
#
# input_file_path
# portfolio_transactions
# csvfile
# csvreader
# csv_header
# portfolio_df
# stock_key
# stock_list
# group
# portfolio2_df
# min_stock_dates
# yesterday
# stock_dict
# count
# url
# parsed
# datetime_obj
# date_obj
# first_purchase_date
# count2
# daily_dict
# daily_list_of_dict
# stock_dict_copy
# stock_dict_copy2
# ticker_stats_df
# ticker_stats_df_T
# daily_closing_df
# aapl_df
# goog_df
# tsla_df
# closing_df
# date
# price
# stock_name
# closing_price_df
# portfolio3_df
# max_date
# holdings_df
# sector_df
# current_industry_holdings
# holdings_contribution_pie
# holdings_shares_pie
# holdings_value_pie
# industry_holdings
# industry_contribution_pie
# industry_shares_pie
# industry_value_pie
# sector_holdings
# sector_contribution_pie
# sector_shares_pie
# sector_value_pie
# industry_analysis
# sector_analysis
# current_holdings
# dashboard

# %% [markdown]
# Names used (sorted):
#
# aapl_df
# closing_df
# closing_price_df
# count
# count2
# csv_header
# csvfile
# csvreader
# current_holdings
# current_industry_holdings
# daily_closing_df
# daily_dict
# daily_list_of_dict
# dashboard
# date
# date_obj
# datetime_obj
# first_purchase_date
# goog_df
# group
# holdings_contribution_pie
# holdings_df
# holdings_shares_pie
# holdings_value_pie
# industry_analysis
# industry_contribution_pie
# industry_holdings
# industry_shares_pie
# industry_value_pie
# input_file_path
# min_stock_dates
# max_date
# parsed
# portfolio_df
# portfolio_transactions
# portfolio2_df
# portfolio3_df
# price
# sector_analysis
# sector_contribution_pie
# sector_df
# sector_holdings
# sector_shares_pie
# sector_value_pie
# stock_dict
# stock_dict_copy
# stock_dict_copy2
# stock_key
# stock_list
# stock_name
# ticker_stats_df
# ticker_stats_df_T
# tsla_df
# url
# yesterday
